# %%
from logic4e import HybridWumpusAgent, WumpusKB, WumpusSATKB, percept_glitter
from wumpus_mat_sat import WumpusKBMatSat
from agents import Glitter, Bump, Stench, Breeze, Scream
from agents4e import WumpusEnvironment, WumpusTestEnvironment

LABELS = ["Stench", "Breeze", "Glitter", "Bump", "Scream"]
EVENT_CLASSES = [Stench, Breeze, Glitter, Bump, Scream]
print(percept_glitter(3))
def to_event(percept_tuple):
    if percept_tuple is None:
        return None
    flags = [bool(x) for x in percept_tuple]
    if not any(flags):
        return None
    if sum(flags) > 1:
        # Original KB only handles one positive percept at a time
        raise ValueError("Multiple positives in percept; logic4e expects one.")
    idx = flags.index(True)
    return EVENT_CLASSES[idx]()  # e.g., Breeze()

def show(step, percept, action):
    active = [lab for lab, v in zip(LABELS, percept) if v]
    name = ", ".join(active) if active else "None"
    print(f"t={step:02d}  percept={name:<20} -> action={action}")

agent = HybridWumpusAgent(dimentions=4, kb_class=WumpusKBMatSat)
env = WumpusTestEnvironment(agent.program, width=4, height=4, show=True)
env.run(4)
# Out:
# Glitter(3)
# === INITIAL WORLD STATE ===
# #   #   #   #
# #   .   W   #
# #   A>  .   #
# #   #   #   #
#
# === SIMULATION STEPS ===
# Agent: <Wumpus>
# Step 1:
#   Percept: Right: Bump | Up: Bump
#   Action:
# Agent: <Explorer>
# Step 1:
#   Percept: Left: Bump | Down: Bump
#   Action: TurnLeft
#   Executing action '' for Wumpus at (2, 2)
#   Executing action 'TurnLeft' for Explorer at (1, 1)
#   World after action:
# #   #   #   #
# #   .   W   #
# #   A^  .   #
# #   #   #   #
#
# Agent: <Wumpus>
# Step 2:
#   Percept: Right: Bump | Up: Bump
#   Action:
# Agent: <Explorer>
# Step 2:
#   Percept: Left: Bump | Down: Bump
#   Action: Forward
#   Executing action '' for Wumpus at (2, 2)
#   Executing action 'Forward' for Explorer at (1, 1)
#   World after action:
# #   #   #   #
# #   A^  W   #
# #   .   .   #
# #   #   #   #
#
# Agent: <Wumpus>
# Step 3:
#   Percept: Left: Explorer | Right: Bump | Up: Bump
#   Action:
# Agent: <Explorer>
# the kb is {(Forward(0) | FacingNorth(0) | FacingWest(0) | L(1, 2, 0) | L(2, 2, 0) | ~L(2, 2, 1)), (Forward(0) | ~Bump(1) | ~Bump(1) | Forward(0) | L(3, 2, 0) | ~L(3, 2, 1)), (FacingSouth(1) | FacingNorth(1) | L(4, 3, 1) | Forward(1) | ~Forward(1) | Bump(2) | ~L(3, 3, 2)), (FacingNorth(0) | Forward(0) | L(4, 4, 0) | ~L(4, 4, 1)), (FacingSouth(1) | L(2, 1, 1) | ~Bump(2) | ~Bump(2) | L(2, 2, 1) | ~L(2, 2, 2)), (Forward(0) | ~L(3, 4, 0) | L(3, 4, 1)), (L(2, 4, 0) | L(2, 2, 0) | L(3, 3, 0) | FacingEast(0) | ~Forward(0) | Bump(1) | ~L(2, 3, 1)), (L(3, 3, 0) | L(4, 4, 0) | FacingEast(0) | L(3, 4, 0) | ~L(3, 4, 1)), (Forward(1) | ~Bump(2) | L(3, 2, 1) | Forward(1) | ~Forward(1) | Bump(2) | ~L(2, 2, 2)), (~P(3, 2) | ~OK(3, 2, 1)), (Forward(1) | L(3, 2, 1) | Forward(1) | ~Bump(2) | ~Forward(1) | Bump(2) | ~L(3, 3, 2)), (L(1, 4, 1) | FacingNorth(1) | ~Bump(2) | ~Forward(1) | Bump(2) | ~L(1, 3, 2)), (FacingSouth(0) | Forward(0) | L(4, 3, 0) | L(2, 3, 0) | L(3, 3, 0) | ~L(3, 3, 1)), (L(2, 3, 0) | FacingNorth(0) | Forward(0) | FacingEast(0) | L(2, 2, 0) | ~L(2, 2, 1)), (~Bump(1) | L(4, 1, 0) | ~Bump(1) | ~Forward(0) | Bump(1) | ~L(3, 1, 1)), (FacingSouth(0) | FacingNorth(0) | L(3, 2, 0) | ~Forward(0) | Bump(1) | ~L(4, 2, 1)), (~Bump(2) | Forward(1) | Forward(1) | FacingEast(1) | ~Forward(1) | Bump(2) | ~L(2, 3, 2)), (Forward(1) | L(2, 1, 1) | L(3, 2, 1) | Forward(1) | L(2, 2, 1) | ~L(2, 2, 2)), (~Bump(1) | L(3, 1, 0) | ~Bump(1) | ~Bump(1) | ~Forward(0) | Bump(1) | ~L(3, 2, 1)), (FacingSouth(1) | L(4, 1, 1) | FacingEast(1) | ~Forward(1) | Bump(2) | ~L(3, 1, 2)), (L(2, 4, 1) | ~Bump(2) | ~Bump(2) | ~Bump(2) | L(2, 3, 1) | ~L(2, 3, 2)), (L(2, 3, 0) | ~Bump(1) | FacingWest(0) | L(1, 2, 0) | L(2, 2, 0) | ~L(2, 2, 1)), (Forward(0) | L(3, 2, 0) | FacingWest(0) | ~Bump(1) | L(3, 3, 0) | ~L(3, 3, 1)), (~P(2, 2) | B(2, 3)), (WumpusAlive(2) | OK(2, 4, 2) | P(2, 4)), (Forward(1) | FacingNorth(1) | FacingWest(1) | FacingEast(1) | L(3, 3, 1) | ~L(3, 3, 2)), (L(3, 2, 1) | Forward(1) | L(2, 1, 1) | L(3, 1, 1) | ~L(3, 1, 2)), (L(2, 3, 1) | FacingNorth(1) | Forward(1) | FacingEast(1) | ~Forward(1) | Bump(2) | ~L(2, 2, 2)), (Forward(1) | FacingNorth(1) | L(3, 3, 1) | FacingEast(1) | L(2, 3, 1) | ~L(2, 3, 2)), (~Bump(2) | ~Bump(2) | L(4, 3, 1) | Forward(1) | L(3, 3, 1) | ~L(3, 3, 2)), (FacingSouth(1) | ~Bump(2) | Forward(1) | FacingEast(1) | L(3, 3, 1) | ~L(3, 3, 2)), (Forward(1) | ~Bump(2) | Forward(1) | FacingEast(1) | ~Forward(1) | Bump(2) | ~L(3, 3, 2)), (FacingSouth(1) | Forward(1) | Forward(1) | ~Forward(1) | Bump(2) | ~L(4, 2, 2)), (~Bump(2) | L(2, 2, 1) | Forward(1) | ~Bump(2) | ~Forward(1) | Bump(2) | ~L(2, 3, 2)), (~Bump(2) | Forward(1) | L(1, 1, 1) | L(2, 1, 1) | ~L(2, 1, 2)), (L(2, 4, 0) | L(2, 2, 0) | ~Bump(1) | L(1, 3, 0) | ~Forward(0) | Bump(1) | ~L(2, 3, 1)), (FacingSouth(0) | Forward(0) | ~Bump(1) | ~Forward(0) | Bump(1) | ~L(4, 3, 1)), (~P(2, 3) | B(2, 4)), (Forward(1) | L(3, 4, 1) | ~Forward(1) | Bump(2) | ~L(4, 4, 2)), (Forward(0) | Forward(0) | L(4, 3, 0) | Forward(0) | ~Forward(0) | Bump(1) | ~L(3, 3, 1)), (~Bump(1) | FacingNorth(0) | ~Bump(1) | FacingEast(0) | L(2, 2, 0) | ~L(2, 2, 1)), (~P(2, 4) | ~OK(2, 4, 1)), (L(3, 2, 0) | Forward(0) | ~Bump(1) | ~Forward(0) | Bump(1) | ~L(3, 1, 1)), (FacingNorth(0) | Forward(0) | ~Forward(0) | Bump(1) | ~L(4, 4, 1)), (FacingSouth(0) | FacingNorth(0) | Forward(0) | L(1, 2, 0) | L(2, 2, 0) | ~L(2, 2, 1)), (~Bump(1) | Forward(0) | ~Bump(1) | FacingEast(0) | ~Forward(0) | Bump(1) | ~L(2, 3, 1)), (Forward(1) | L(1, 1, 1) | Forward(1) | L(1, 2, 1) | ~L(1, 2, 2)), (WumpusAlive(2) | OK(2, 2, 2) | P(2, 2)), (~Bump(2) | Forward(1) | ~Bump(2) | ~Bump(2) | L(2, 2, 1) | ~L(2, 2, 2)), (Forward(1) | L(2, 2, 1) | FacingWest(1) | L(1, 3, 1) | L(2, 3, 1) | ~L(2, 3, 2)), (Forward(1) | ~Bump(2) | L(4, 2, 1) | Forward(1) | ~Forward(1) | Bump(2) | ~L(3, 2, 2)), (~Bump(1) | Forward(0) | Forward(0) | ~Forward(0) | Bump(1) | ~L(1, 2, 1)), (L(3, 3, 1) | ~Bump(2) | Forward(1) | FacingEast(1) | ~Forward(1) | Bump(2) | ~L(3, 2, ...
# Step 3:
#   Percept: Left: Bump | Right: Stench | Up: Bump
#   Action: Grab
#   Executing action '' for Wumpus at (2, 2)
#   Executing action 'Grab' for Explorer at (1, 2)
#   World after action:
# #   #   #   #
# #   A^  W   #
# #   .   .   #
# #   #   #   #
#
# Agent: <Wumpus>
# Step 4:
#   Percept: Left: Explorer | Right: Bump | Up: Bump
#   Action:
# Agent: <Explorer>
# the kb is {(Forward(2) | ~Bump(3) | Forward(2) | L(1, 3, 2) | ~L(1, 3, 3)), (Forward(0) | FacingNorth(0) | FacingWest(0) | L(1, 2, 0) | L(2, 2, 0) | ~L(2, 2, 1)), (Forward(0) | ~Bump(1) | ~Bump(1) | Forward(0) | L(3, 2, 0) | ~L(3, 2, 1)), (L(2, 4, 2) | ~Bump(3) | L(3, 3, 2) | Forward(2) | L(2, 3, 2) | ~L(2, 3, 3)), (FacingSouth(1) | FacingNorth(1) | L(4, 3, 1) | Forward(1) | ~Forward(1) | Bump(2) | ~L(3, 3, 2)), (FacingNorth(0) | Forward(0) | L(4, 4, 0) | ~L(4, 4, 1)), (~Bump(3) | L(4, 2, 2) | FacingEast(2) | L(4, 3, 2) | ~L(4, 3, 3)), (FacingSouth(1) | L(2, 1, 1) | ~Bump(2) | ~Bump(2) | L(2, 2, 1) | ~L(2, 2, 2)), (Forward(0) | ~L(3, 4, 0) | L(3, 4, 1)), (L(2, 4, 0) | L(2, 2, 0) | L(3, 3, 0) | FacingEast(0) | ~Forward(0) | Bump(1) | ~L(2, 3, 1)), (L(3, 3, 0) | L(4, 4, 0) | FacingEast(0) | L(3, 4, 0) | ~L(3, 4, 1)), (Forward(1) | ~Bump(2) | L(3, 2, 1) | Forward(1) | ~Forward(1) | Bump(2) | ~L(2, 2, 2)), (~P(3, 2) | ~OK(3, 2, 1)), (FacingSouth(2) | ~Bump(3) | FacingWest(2) | FacingEast(2) | ~Forward(2) | Bump(3) | ~L(3, 3, 3)), (L(3, 4, 2) | FacingNorth(2) | L(4, 3, 2) | Forward(2) | L(3, 3, 2) | ~L(3, 3, 3)), (Forward(1) | L(3, 2, 1) | Forward(1) | ~Bump(2) | ~Forward(1) | Bump(2) | ~L(3, 3, 2)), (L(1, 4, 1) | FacingNorth(1) | ~Bump(2) | ~Forward(1) | Bump(2) | ~L(1, 3, 2)), (L(2, 3, 2) | L(2, 1, 2) | FacingWest(2) | FacingEast(2) | ~Forward(2) | Bump(3) | ~L(2, 2, 3)), (FacingSouth(2) | Forward(2) | ~Bump(3) | L(1, 2, 2) | ~Forward(2) | Bump(3) | ~L(2, 2, 3)), (FacingSouth(0) | Forward(0) | L(4, 3, 0) | L(2, 3, 0) | L(3, 3, 0) | ~L(3, 3, 1)), (L(2, 3, 0) | FacingNorth(0) | Forward(0) | FacingEast(0) | L(2, 2, 0) | ~L(2, 2, 1)), (~Bump(1) | L(4, 1, 0) | ~Bump(1) | ~Forward(0) | Bump(1) | ~L(3, 1, 1)), (FacingSouth(0) | FacingNorth(0) | L(3, 2, 0) | ~Forward(0) | Bump(1) | ~L(4, 2, 1)), (~Bump(2) | Forward(1) | Forward(1) | FacingEast(1) | ~Forward(1) | Bump(2) | ~L(2, 3, 2)), (FacingSouth(2) | Forward(2) | FacingEast(2) | ~Forward(2) | Bump(3) | ~L(4, 2, 3)), (Forward(1) | L(2, 1, 1) | L(3, 2, 1) | Forward(1) | L(2, 2, 1) | ~L(2, 2, 2)), (~Bump(1) | L(3, 1, 0) | ~Bump(1) | ~Bump(1) | ~Forward(0) | Bump(1) | ~L(3, 2, 1)), (~Bump(3) | L(4, 4, 2) | L(2, 4, 2) | L(3, 4, 2) | ~L(3, 4, 3)), (FacingSouth(1) | L(4, 1, 1) | FacingEast(1) | ~Forward(1) | Bump(2) | ~L(3, 1, 2)), (L(2, 4, 1) | ~Bump(2) | ~Bump(2) | ~Bump(2) | L(2, 3, 1) | ~L(2, 3, 2)), (Breeze(3) | ~B(3, 1) | ~L(3, 1, 3)), (L(3, 3, 2) | FacingNorth(2) | Forward(2) | ~Bump(3) | L(3, 2, 2) | ~L(3, 2, 3)), (Forward(2) | ~Bump(3) | ~Bump(3) | L(2, 3, 2) | L(3, 3, 2) | ~L(3, 3, 3)), (L(1, 3, 2) | Forward(2) | Forward(2) | ~Forward(2) | Bump(3) | ~L(1, 2, 3)), (L(2, 3, 0) | ~Bump(1) | FacingWest(0) | L(1, 2, 0) | L(2, 2, 0) | ~L(2, 2, 1)), (Forward(0) | L(3, 2, 0) | FacingWest(0) | ~Bump(1) | L(3, 3, 0) | ~L(3, 3, 1)), (~Bump(3) | ~Bump(3) | Forward(2) | FacingEast(2) | L(2, 2, 2) | ~L(2, 2, 3)), (~P(2, 2) | B(2, 3)), (WumpusAlive(2) | OK(2, 4, 2) | P(2, 4)), (Forward(2) | FacingNorth(2) | ~Bump(3) | ~Forward(2) | Bump(3) | ~L(4, 3, 3)), (Forward(1) | FacingNorth(1) | FacingWest(1) | FacingEast(1) | L(3, 3, 1) | ~L(3, 3, 2)), (L(3, 2, 1) | Forward(1) | L(2, 1, 1) | L(3, 1, 1) | ~L(3, 1, 2)), (L(2, 3, 1) | FacingNorth(1) | Forward(1) | FacingEast(1) | ~Forward(1) | Bump(2) | ~L(2, 2, 2)), (Forward(1) | FacingNorth(1) | L(3, 3, 1) | FacingEast(1) | L(2, 3, 1) | ~L(2, 3, 2)), (L(3, 3, 2) | ~Bump(3) | L(4, 2, 2) | FacingEast(2) | L(3, 2, 2) | ~L(3, 2, 3)), (Forward(2) | ~Bump(3) | Forward(2) | L(2, 2, 2) | ~Forward(2) | Bump(3) | ~L(3, 2, 3)), (~Bump(2) | ~Bump(2) | L(4, 3, 1) | Forward(1) | L(3, 3, 1) | ~L(3, 3, 2)), (FacingNorth(2) | L(4, 4, 2) | L(2, 4, 2) | L(3, 4, 2) | ~L(3, 4, 3)), (Forward(2) | Forward(2) | L(3, 3, 2) | Forward(2) | L(2, 3, 2) | ~L(2, 3, 3)), (FacingSouth(1) | ~Bump(2) | Forward(1) | FacingEast(1) | L(3, 3, 1) | ~L(3, 3, 2)), (Forward(1) | ~Bump(2) | Forward(1) | FacingEast(1) | ~Forward(1) | Bump(2) | ~L(3, 3, 2)), (FacingSouth(1) | Forward(1) | Forward(1) | ...
# Step 4:
#   Percept: Left: Bump | Right: Stench | Up: Bump
#   Action: Climb
#   Executing action '' for Wumpus at (2, 2)
#   Executing action 'Climb' for Explorer at (1, 2)
#   World after action:
# #   #   #   #
# #   A^  W   #
# #   .   .   #
# #   #   #   #
