# %%
from logic4e import HybridWumpusAgent, WumpusKB, WumpusSATKB
from wumpus_mat_sat import WumpusKBMatSat
from agents import Glitter, Bump, Stench, Breeze, Scream
from agents4e import WumpusEnvironment, WumpusTestEnvironment

LABELS = ["Stench", "Breeze", "Glitter", "Bump", "Scream"]
EVENT_CLASSES = [Stench, Breeze, Glitter, Bump, Scream]

def to_event(percept_tuple):
    if percept_tuple is None:
        return None
    flags = [bool(x) for x in percept_tuple]
    if not any(flags):
        return None
    if sum(flags) > 1:
        # Original KB only handles one positive percept at a time
        raise ValueError("Multiple positives in percept; logic4e expects one.")
    idx = flags.index(True)
    return EVENT_CLASSES[idx]()  # e.g., Breeze()

def show(step, percept, action):
    active = [lab for lab, v in zip(LABELS, percept) if v]
    name = ", ".join(active) if active else "None"
    print(f"t={step:02d}  percept={name:<20} -> action={action}")

agent = HybridWumpusAgent(dimentions=3, kb_class=WumpusSATKB)
env = WumpusTestEnvironment(agent.program, width=3, height=3, show=True)
env.run(100)
# Out:
# {A: True}
# False
# .   .   .
# .   A>  .
# .   .   .
# frontier before adding children PriorityQueue([])
# explored set {<wumpus_types.WumpusPosition object at 0x10685f610>}
# [<Node ([2, 1], RIGHT)>, <Node ([1, 1], UP)>, <Node ([1, 1], DOWN)>]
# [<Node ([2, 1], RIGHT)>, <Node ([1, 1], UP)>, <Node ([1, 1], DOWN)>]
# [<Node ([2, 1], RIGHT)>, <Node ([1, 1], UP)>, <Node ([1, 1], DOWN)>]
# frontier before adding children PriorityQueue([<Node ([1, 1], UP)>, <Node ([2, 1], RIGHT)>])
# explored set {<wumpus_types.WumpusPosition object at 0x10685f610>, <wumpus_types.WumpusPosition object at 0x106ac0770>}
# [<Node ([1, 1], RIGHT)>, <Node ([1, 1], LEFT)>]
# [<Node ([1, 1], RIGHT)>, <Node ([1, 1], LEFT)>]
# frontier before adding children PriorityQueue([<Node ([1, 1], LEFT)>, <Node ([2, 1], RIGHT)>])
# explored set {<wumpus_types.WumpusPosition object at 0x10685f610>, <wumpus_types.WumpusPosition object at 0x106e7ab10>, <wumpus_types.WumpusPosition object at 0x106ac0770>}
# [<Node ([1, 2], UP)>, <Node ([1, 1], LEFT)>, <Node ([1, 1], RIGHT)>]
# [<Node ([1, 2], UP)>, <Node ([1, 1], LEFT)>, <Node ([1, 1], RIGHT)>]
# [<Node ([1, 2], UP)>, <Node ([1, 1], LEFT)>, <Node ([1, 1], RIGHT)>]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 28
#      26 agent = HybridWumpusAgent(dimentions=3, kb_class=WumpusSATKB)
#      27 env = WumpusTestEnvironment(agent.program, width=3, height=3, show=True)
# ---> 28 env.run(100)
#
# File ~/Projects/aima-python/agents4e.py:357, in Environment.run(self, steps)
#     355 if self.is_done():
#     356     return
# --> 357 self.step()
#
# File ~/Projects/aima-python/agents4e.py:345, in Environment.step(self)
#     343 for agent in self.agents:
#     344     if agent.alive:
# --> 345         actions.append(agent.program(self.percept(agent)))
#     346     else:
#     347         actions.append("")
#
# File ~/Projects/aima-python/logic4e.py:1150, in HybridWumpusAgent.execute(self, percept)
#    1148 goals.append([1, 1])
#    1149 self.plan.append("Grab")
# -> 1150 actions = self.plan_route(self.current_position, goals, safe_points)
#    1151 self.plan.extend(actions)
#    1152 self.plan.append("Climb")
#
# File ~/Projects/aima-python/logic4e.py:1203, in HybridWumpusAgent.plan_route(self, current, goals, allowed)
#    1201 def plan_route(self, current, goals, allowed):
#    1202     problem = PlanRoute(current, goals, allowed, self.dimrow)
# -> 1203     return astar_search(problem).solution()
#
# File ~/Projects/aima-python/search.py:424, in astar_search(problem, h, display)
#     420 """A* search is best-first graph search with f(n) = g(n)+h(n).
#     421 You need to specify the h function when you call astar_search, or
#     422 else in your Problem subclass."""
#     423 h = memoize(h or problem.h, 'h')
# --> 424 return best_first_graph_search(problem, lambda n: n.path_cost + h(n), display)
#
# File ~/Projects/aima-python/search.py:271, in best_first_graph_search(problem, f, display)
#     269 node = Node(problem.initial)
#     270 frontier = PriorityQueue('min', f)
# --> 271 frontier.append(node)
#     272 explored = set()
#     273 while frontier:
#
# File ~/Projects/aima-python/utils.py:740, in PriorityQueue.append(self, item)
#     738 def append(self, item):
#     739     """Insert item at its correct position."""
# --> 740     heapq.heappush(self.heap, (self.f(item), item))
#
# File ~/Projects/aima-python/utils.py:417, in memoize.<locals>.memoized_fn(obj, *args)
#     415     return getattr(obj, slot)
#     416 else:
# --> 417     val = fn(obj, *args)
#     418     setattr(obj, slot, val)
#     419     return val
#
# File ~/Projects/aima-python/search.py:424, in astar_search.<locals>.<lambda>(n)
#     420 """A* search is best-first graph search with f(n) = g(n)+h(n).
#     421 You need to specify the h function when you call astar_search, or
#     422 else in your Problem subclass."""
#     423 h = memoize(h or problem.h, 'h')
# --> 424 return best_first_graph_search(problem, lambda n: n.path_cost + h(n), display)
#
# File ~/Projects/aima-python/utils.py:417, in memoize.<locals>.memoized_fn(obj, *args)
#     415     return getattr(obj, slot)
#     416 else:
# --> 417     val = fn(obj, *args)
#     418     setattr(obj, slot, val)
#     419     return val
#
# File ~/Projects/aima-python/search.py:581, in PlanRoute.h(self, node)
#     579 # Manhattan Heuristic Function
#     580 x1, y1 = node.state.get_location()
# --> 581 x2, y2 = self.goal
#     583 return abs(x2 - x1) + abs(y2 - y1)
#
# ValueError: not enough values to unpack (expected 2, got 1)
